# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
html = requests.get ("https://www.incometaxindia.gov.in/lists/exempted%20institutions/allitems.aspx")
soup = bs(html.content, "lxml")
main_table = soup.find("table", class_= "ms-listviewtable")
table_row = []

for elem in main_table.find("tr",class_="ms-viewheadertr ms-vhltr"):#.replace("\xa0\xa0", ""):
    table_row.append(elem.text.replace("\xa0\xa0", ""))
print (table_row)
# table_row.append(table_row1)
# print (table_row)
# for i in table_row:
#     print (i)
# table_dict= {}
# table_dict["Title"] = cells[0].find(text=True)
#                     table_dict["Address"] = cells[1].find(text=True)
#                     table_dict["City"] = cells[2].find(text=True)
#                     table_dict["State"] = cells[3].find(text=True)
#                     table_dict["CCITCCA"] = cells[4].find(text=True)
#                     table_dict["CCIT"] = cells[5].find(text=True)
#                     table_dict["CIT"] = cells[6].find(text=True)
#                     table_dict["Section_Number"] = cells[7].find(text=True)
#                     table_dict["PAN"] = cells[8].find(text=True)
#                     table_dict["Order_Date"] = cells[9].find(text=True)
#                     table_dict["Withdrawn_Date"] = cells[10].find(text=True)
#                     table_dict["Active"] = cells[11].find(text=True)
#                     table_dict["Approval_Status"] = cells[12].find(text=True)
#                     table_dict["Notification_Number"] = cells[13].find(text=True)
#                     table_dict["Nature"] = cells[14].find(text=True)
#                     table_dict["Remarks"] = cells[15].find(text=True)
#                     table_dict["Sort_Order"] = cells[16].find(text=True)
#                     table_dict["Modified"] = cells[17].find(text=True)
#                     table_dict["Expiry_Date"] = cells[18].find(text=True)
#                     table_dict["Modified_By"] = cells[19].find(text=True)
# Out:
# ['', 'Title', 'Address', 'City', 'State', 'CCITCCA', 'CCIT', 'CIT', 'Section Number', 'PAN', 'Order Date', 'Withdrawn Date', 'Active', 'Approval Status', 'Notification Number', 'Nature', 'Remarks', 'Sort Order', 'Modified', 'ExpiryDate', 'Modified By']

# %%
html = requests.get ("https://www.incometaxindia.gov.in/lists/exempted%20institutions/allitems.aspx")
soup = bs(html.content, "lxml")
main_table = soup.find("table", class_= "ms-listviewtable")
cell = main_table.find_all("tr")
table_row1 = []
for c in cell:
    table_row1.append(c.text)
# Out:
# ['Title\xa0\xa0AddressCity\xa0\xa0State\xa0\xa0CCITCCA\xa0\xa0CCIT\xa0\xa0CIT\xa0\xa0Section Number\xa0\xa0PAN\xa0\xa0Order Date\xa0\xa0Withdrawn Date\xa0\xa0Active\xa0\xa0Approval Status\xa0\xa0Notification Number\xa0\xa0Nature\xa0\xa0RemarksSort Order\xa0\xa0Modified\xa0\xa0ExpiryDate\xa0\xa0Modified By\xa0\xa0',
#  'AAATV6182A\xa0\xa01/1/1970NoApproved10/29/2014 7:01 PMSystem Account',
#  'Bibek Anander Satsang\xa0\xa0Tripura West, AgartalaAAATB-79351/1/1970NoApproved10/29/2014 7:01 PMSystem Account',
#  'Bharti Jan\xa0\xa01/1/1970NoApproved10/29/2014 7:01 PMSystem Account',
#  'Bharti Jan\xa0\xa01/1/1970NoApproved10/29/2014 7:01 PMSystem Account',
#  'SRI KRISNA GUBHBEDAI SEWA SAMITI\xa0\xa0RAMNAGARBARABANKIUTTAR PRADESH12A3/31/2009YesApproved6/29/2014 1:22 PMSystem Account',
#  'NARAYAN CHETNA SANSTHAN\xa0\xa0SHANTIPURAMBARABANKIUTTAR PRADESH12A3/24/2009YesApproved6/29/2014 1:22 PMSystem Account',
# ...
